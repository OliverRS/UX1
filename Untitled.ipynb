# %%
import pandas as pd

# %%
UX_dc = pd.read_csv('UXDataCollection.csv')

# %%
len(UX_dc)
# Out:
# 5

# %%
UX_dc.describe()
# Out:
#        Hvor høj er du?  Hvor gammel er du?
# count         5.000000            5.000000
# mean        176.800000           21.400000
# std          14.411801            1.516575
# min         162.000000           20.000000
# 25%         164.000000           21.000000
# 50%         178.000000           21.000000
# 75%         183.000000           21.000000
# max         197.000000           24.000000

# %%
# The data was collected through the use of convenience sampling, as all the data comes from my classmates

# %%
# A potential bias from the collected data could for example be, that all the sampled subjects used Apple IOS, as Apple is significantly more common with younger people in comparison to other OIS'
